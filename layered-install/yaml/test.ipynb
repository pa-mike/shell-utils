# %%
from entry import bash_command

bash_command("echo hello")
# Out:
# CompletedProcess(args=['bash', '-c', 'ls'], returncode=0, stdout=b'__pycache__\nentry.py\nfunctions.ps1\nfunctions.sh\ntest.ipynb\n', stderr=b'')

# %%
a = bash("pwd")

# %%
a.stdout.decode('UTF-8')
# Out:
# '/home/mrgibbon/engineering-handbook/scripts/onboarding/layered-install/pymethod\n'

# %%
# %pip install pyyaml
# Out:
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (682 kB)
#      |████████████████████████████████| 682 kB 2.9 MB/s
# Installing collected packages: pyyaml
# Successfully installed pyyaml-6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !ls
# Out:
# __pycache__	entry.ps1  functions.sh  tools.yaml  wsl-distros.yaml
# base_utils.ps1	entry.py   test.ipynb	 utils.ps1

# %%
from munch import Munch

# %%
import yaml
from munch import Munch
toolYaml = Munch()

with open('tools.yaml') as f:
    toolYaml = Munch.fromYAML(f)

# %%
instance = []
method = []
params = []
parm2 = []

targeta = ['bash','apt-get','powershell']
targetb = ['cask','winget','formulae']

for k,v in toolYaml.components.tools.items():
    print(k)
    if k not in instance:
        instance.append(k)
    for a,b in v.items():
        if a not in method:
            method.append(a)
        c = b.split(";")
        if c[0] not in params:
            params.append(c[0])
        if a+c[0] not in parm2:
            parm2.append(a+c[0])
        if a in targeta:
            if a == 'brew':
                toolYaml.components.tools[k].update({a:{'source':c[0], 'pkg':c[1]}})
            elif a == "winget":
                toolYaml.components.tools[k].update({a:{'source':c[0], 'pkg':c[1]}})
            elif a == "apt-get":
                toolYaml.components.tools[k].update({a:{'pkg':c[0]}})
            elif a == 'bash':
                toolYaml.components.tools[k].update({a:{'script':c[0]}})
            elif a == 'powershell':
                toolYaml.components.tools[k].update({a:{'script':c[0]}})
            
            print("TARGETA",k,a,b)
        if c[0] in targetb:
            if a == 'brew':
                toolYaml.components.tools[k].update({a:{'source':c[0], 'pkg':c[1]}})
            elif a == "winget":
                toolYaml.components.tools[k].update({a:{'source':c[0], 'pkg':c[1]}})
            elif a == "apt-get":
                toolYaml.components.tools[k].update({a:{'pkg':c[0]}})
            elif a == 'bash':
                toolYaml.components.tools[k].update({a:{'script':c[0]}})
            elif a == 'powershell':
                toolYaml.components.tools[k].update({a:{'script':c[0]}})
            
            print("TARGETB",k,a,b)
# Out:
# exampletool
# azurecli
# azurestorage
# chrome
# conda
# curl
# dbeaverce
# devenv
# dirstat
# docker
# everything
# git
# github
# googledrive
# maven
# miro
# notion
# office
# onedrive
# openjdk11
# plaintxteditor
# postman
# python
# sejdapdf
# sevenzip
# ssh
# vlc
# vscode
# windowmanager
# zoom

# %%
print(toolYaml.toYAML())
# Out:
# class:
#     object:
#         instance:
#             method:
#                 params: executables
# components:
#     ide-extensions:
#         vscode: pa-data-team.vsix
#     tools:
#         azurecli:
#             brew: formulae;azure-cli
#             winget: winget;Microsoft.AzureCLI
#         azurestorage:
#             brew: cask;microsoft-azure-storage-explorer
#             winget: winget;Microsoft.AzureStorageExplorer
#         chrome:
#             brew: cask;google-chrome
#             winget: winget;Google.Chrome
#         conda:
#             bash: install-conda.sh
#         curl:
#             apt-get: curl
#         dbeaverce:
#             brew: cask;dbeaver-community
#             winget: winget;dbeaver.dbeaver
#         devenv:
#             bash: devenv.sh
#             powershell: devenv.ps1
#         dirstat:
#             brew: cask;disk-inventory-x
#             winget: winget;WinDirStat.WinDirStat
#         docker:
#             brew: cask;docker
#             winget: winget;Docker.DockerDesktop
#         everything:
#             brew: cask;easyfind
#             winget: winget;voidtools.Everything
#         exampletool:
#             apt:
#                 args: argstring
#                 pkg: id
#             apt-get:
#                 args: argstring
#                 pkg: id
#             bash:
#                 args: argstring
#                 script: scriptname.sh
#             brew:
#                 args: argstring
#                 pkg: id
#                 source: cask
#             powershell:
#                 args: argstring
#                 script: scriptname.ps1
#             winget:
#                 args: argstring
#                 pkg: id
#                 source: cask
#         git:
#             brew: formulae;git
#             winget: winget;Git.Git
#         github:
#             brew: cask;github
#             winget: winget;GitHub.GitHubDesktop
#         googledrive:
#             brew: cask;google-drive
#             winget: winget;Google.BackupAndSync
#         maven:
#             apt-get: maven
#         miro:
#             brew: cask;miro
#             winget: winget;Miro.Miro
#         notion:
#             brew: cask;notion
#             winget: winget;Notion.Notion
#         office:
#             brew: cask;microsoft-office
#             winget: winget;Microsoft.officedeploymenttool
#         onedrive:
#             brew: cask;onedrive
#             winget: winget;Microsoft.OneDrive
#         openjdk11:
#             apt-get: openjdk-11-jdk
#         plaintxteditor:
#             brew: cask;coteditor
#             winget: winget;Notepad++.Notepad++
#         postman:
#             brew: cask;postman
#             winget: winget;Postman.Postman
#         python:
#             bash: install-python.sh
#             winget: winget;Python.Python.3
#         sejdapdf:
#             brew: cask;sejda-pdf
#             winget: winget;Sejda.PDFDesktop
#         sevenzip:
#             brew: formulae;sevenzip
#             winget: winget;7zip.7zip
#         ssh:
#             winget: winget;PuTTY.PuTTY
#         vlc:
#             brew: cask;vlc
#             winget: winget;VideoLAN.VLC
#         vscode:
#             brew: cask;visual-studio-code
#             winget: winget;Microsoft.VisualStudioCode
#         windowmanager:
#             brew: cask;bettertouchtool
#             winget: winget;Microsoft.PowerToys
#         zoom:
#             brew: cask;zoom
#             winget: winget;Zoom.Zoom
#     utilities:
#         open-here-shell:
#             regedit: open-here.reg
# flows:
#     business:
#     - base
#     - qol
#     - business
#     data:
#     - base
#     - qol
#     - devbase
#     - data
#     dev:
#     - base
#     - qol
#     - devbase
#     - dev
# stages:
#     base:
#         tools:
#         - chrome
#         - notion
#         - googledrive
#         - miro
#         - python
#     business:
#         tools:
#         - onedrive
#         - office
#         - zoom
#     data:
#         devenv:
#         - conda
#         - python
#         ide-extensions:
#         - pa-data-team.vsix
#         tools:
#         - dbeaverce
#         - azurestorage
#         - conda
#     devbase:
#         devenv:
#         - python
#         - conda
#         - openjdk11
#         - maven
#         tools:
#         - vscode
#         - docker
#         - git
#         - github
#         - ssh
#         - azurecli
#         - postman
#         - devenv
#         utilites:
#         - open-here-shell
#     qol:
#         tools:
#         - vlc
#         - everything
#         - windowmanager
#         - sevenzip
#         - plaintxteditor
#         - dirstat
#         - sejdapdf

# %%
from munch import Munch
toolYaml = Munch()

with open('tools.yaml') as f:
    toolYaml = Munch.fromYAML(f)
instance = []
method = []
methoddetails = {}
params = []
for tool,tooldict in toolYaml.components.tools.items():
    print(tool)
    if tool not in instance:
        instance.append(tool)
    for methods,method_dict in tooldict.items():
        if methods not in method:
            method.append(methods)
            methoddetails[methods] = []
        for param,executable in method_dict.items():
            if param not in params:
                params.append(param)
            if param not in methoddetails[methods]:
                methoddetails[methods].append(param)
# Out:
# exampletool
# azurecli
# azurestorage
# chrome
# conda
# curl
# dbeaverce
# devenv
# dirstat
# docker
# everything
# git
# github
# googledrive
# maven
# miro
# notion
# office
# onedrive
# openjdk11
# plaintxteditor
# postman
# python
# sejdapdf
# sevenzip
# ssh
# vlc
# vscode
# windowmanager
# zoom
# restart-script

# %%
instance
# Out:
# ['exampletool',
#  'azurecli',
#  'azurestorage',
#  'chrome',
#  'conda',
#  'curl',
#  'dbeaverce',
#  'devenv',
#  'dirstat',
#  'docker',
#  'everything',
#  'git',
#  'github',
#  'googledrive',
#  'maven',
#  'miro',
#  'notion',
#  'office',
#  'onedrive',
#  'openjdk11',
#  'plaintxteditor',
#  'postman',
#  'python',
#  'sejdapdf',
#  'sevenzip',
#  'ssh',
#  'vlc',
#  'vscode',
#  'windowmanager',
#  'zoom',
#  'restart-script']

# %%
method
import yaml
print(yaml.safe_dump(method))
# Out:
# - brew
# - winget
# - apt
# - apt-get
# - bash
# - powershell

# %%
params
params
import yaml
print(yaml.safe_dump(params))
# Out:
# - source
# - args
# - pkg
# - script

# %%
print(yaml.safe_dump([{'brew': ['source', 'args', 'pkg']},
 {'winget': ['source', 'args', 'pkg']},
 {'apt': ['args', 'pkg']},
 {'apt-get': ['args', 'pkg']},
 {'bash': ['script', 'args']},
 {'powershell': ['script', 'args']}]))
# Out:
# - brew:
#   - source
#   - args
#   - pkg
# - winget:
#   - source
#   - args
#   - pkg
# - apt:
#   - args
#   - pkg
# - apt-get:
#   - args
#   - pkg
# - bash:
#   - script
#   - args
# - powershell:
#   - script
#   - args

# %%
methoddetails
# Out:
# {'brew': ['source', 'args', 'pkg'],
#  'winget': ['source', 'args', 'pkg'],
#  'apt': ['args', 'pkg'],
#  'apt-get': ['args', 'pkg'],
#  'bash': ['script', 'args'],
#  'powershell': ['script', 'args']}

# %%
import yaml
print(yaml.safe_dump(methoddetails))
# Out:
# apt:
# - args
# - pkg
# apt-get:
# - args
# - pkg
# bash:
# - script
# - args
# brew:
# - source
# - args
# - pkg
# powershell:
# - script
# - args
# winget:
# - source
# - args
# - pkg

# %%
yaml.safe_load('''apiVersion: apps/v1
kind: Deployment
metadata:
  name: nginx-deployment
  labels:
    app: nginx
spec:
  replicas: 3
  selector:
    matchLabels:
      app: nginx
  template:
    metadata:
      labels:
        app: nginx
    spec:
      containers:
      - name: nginx
        image: nginx:1.14.2
        ports:
        - containerPort: 80''')
# Out:
# {'apiVersion': 'apps/v1',
#  'kind': 'Deployment',
#  'metadata': {'name': 'nginx-deployment', 'labels': {'app': 'nginx'}},
#  'spec': {'replicas': 3,
#   'selector': {'matchLabels': {'app': 'nginx'}},
#   'template': {'metadata': {'labels': {'app': 'nginx'}},
#    'spec': {'containers': [{'name': 'nginx',
#       'image': 'nginx:1.14.2',
#       'ports': [{'containerPort': 80}]}]}}}}

# %%
from munch import Munch
toolYaml = Munch()

with open('tools.yaml') as f:
    toolYaml = Munch.fromYAML(f)
    
component_reconstruction = []
all_groups = []
all_components = []
all_methods = []
all_parameters = []
all_values = []

{
    'components':[
        {'name': component,
        'group': group,
        'methods':[
            {method:[
                    {parameter:value}
            ]}
        ]}
    ]
}

def param_dict(parameters):
    parameter_list = []
    for parameter, value in parameters.items():
        if type(value) is dict:
            parameter_list.append({parameter: param_dict(value)})
        parameter_list.append({parameter: value})
    return parameter_list

for group, components in toolYaml.components.items():
    for component, methods in components.items():
        component_reconstruction.append({"handle":component, "type":group, "methods":param_dict(methods)})
        # for method, parameters in methods.items():
        #     for parameter, value in parameters.items():
            
               
               
               
               
               
               
               
               
               
               
               
               
        #         print(group, component, method, parameter, value)

# %%
import yaml
print(yaml.safe_dump(component_reconstruction))
# Out:
# - handle: vscode
#   methods:
#   - extension-pack:
#       source: pa-data-team.vsix
#   type: ide-extensions
# - handle: azurecli
#   methods:
#   - brew:
#       pkg: azure-cli
#       source: formulae
#   - winget:
#       pkg: Microsoft.AzureCLI
#       source: winget
#   type: tools
# - handle: azurestorage
#   methods:
#   - brew:
#       pkg: microsoft-azure-storage-explorer
#       source: cask
#   - winget:
#       pkg: Microsoft.AzureStorageExplorer
#       source: winget
#   type: tools
# - handle: chrome
#   methods:
#   - brew:
#       pkg: google-chrome
#       source: cask
#   - winget:
#       pkg: Google.Chrome
#       source: winget
#   type: tools
# - handle: conda
#   methods:
#   - bash:
#       script: install-conda.sh
#   type: tools
# - handle: curl
#   methods:
#   - apt-get:
#       pkg: curl
#   type: tools
# - handle: dbeaverce
#   methods:
#   - brew:
#       pkg: dbeaver-community
#       source: cask
#   - winget:
#       pkg: dbeaver.dbeaver
#       source: winget
#   type: tools
# - handle: devenv
#   methods:
#   - bash:
#       script: devenv.sh
#   - powershell:
#       script: devenv.ps1
#   type: tools
# - handle: dirstat
#   methods:
#   - brew:
#       pkg: disk-inventory-x
#       source: cask
#   - winget:
#       pkg: WinDirStat.WinDirStat
#       source: winget
#   type: tools
# - handle: docker
#   methods:
#   - brew:
#       pkg: docker
#       source: cask
#   - winget:
#       pkg: Docker.DockerDesktop
#       source: winget
#   type: tools
# - handle: everything
#   methods:
#   - brew:
#       pkg: easyfind
#       source: cask
#   - winget:
#       pkg: voidtools.Everything
#       source: winget
#   type: tools
# - handle: git
#   methods:
#   - brew:
#       pkg: git
#       source: formulae
#   - winget:
#       pkg: Git.Git
#       source: winget
#   type: tools
# - handle: github
#   methods:
#   - brew:
#       pkg: github
#       source: cask
#   - winget:
#       pkg: GitHub.GitHubDesktop
#       source: winget
#   type: tools
# - handle: googledrive
#   methods:
#   - brew:
#       pkg: google-drive
#       source: cask
#   - winget:
#       pkg: Google.BackupAndSync
#       source: winget
#   type: tools
# - handle: maven
#   methods:
#   - apt-get:
#       pkg: maven
#   type: tools
# - handle: miro
#   methods:
#   - brew:
#       pkg: miro
#       source: cask
#   - winget:
#       pkg: Miro.Miro
#       source: winget
#   type: tools
# - handle: notion
#   methods:
#   - brew:
#       pkg: notion
#       source: cask
#   - winget:
#       pkg: Notion.Notion
#       source: winget
#   type: tools
# - handle: office
#   methods:
#   - brew:
#       pkg: microsoft-office
#       source: cask
#   - winget:
#       pkg: Microsoft.officedeploymenttool
#       source: winget
#   type: tools
# - handle: onedrive
#   methods:
#   - brew:
#       pkg: onedrive
#       source: cask
#   - winget:
#       pkg: Microsoft.OneDrive
#       source: winget
#   type: tools
# - handle: openjdk11
#   methods:
#   - apt-get:
#       pkg: openjdk-11-jdk
#   type: tools
# - handle: plaintxteditor
#   methods:
#   - brew:
#       pkg: coteditor
#       source: cask
#   - winget:
#       pkg: Notepad++.Notepad++
#       source: winget
#   type: tools
# - handle: postman
#   methods:
#   - brew:
#       pkg: postman
#       source: cask
#   - winget:
#       pkg: Postman.Postman
#       source: winget
#   type: tools
# - handle: python
#   methods:
#   - bash:
#       script: install-python.sh
#   - winget:
#       pkg: Python.Python.3
#       source: winget
#   type: tools
# - handle: sejdapdf
#   methods:
#   - brew:
#       pkg: sejda-pdf
#       source: cask
#   - winget:
#       pkg: Sejda.PDFDesktop
#       source: winget
#   type: tools
# - handle: sevenzip
#   methods:
#   - brew:
#       pkg: sevenzip
#       source: formulae
#   - winget:
#       pkg: 7zip.7zip
#       source: winget
#   type: tools
# - handle: ssh
#   methods:
#   - winget:
#       pkg: PuTTY.PuTTY
#       source: winget
#   type: tools
# - handle: vlc
#   methods:
#   - brew:
#       pkg: vlc
#       source: cask
#   - winget:
#       pkg: VideoLAN.VLC
#       source: winget
#   type: tools
# - handle: vscode
#   methods:
#   - brew:
#       pkg: visual-studio-code
#       source: cask
#   - winget:
#       pkg: Microsoft.VisualStudioCode
#       source: winget
#   type: tools
# - handle: windowmanager
#   methods:
#   - brew:
#       pkg: bettertouchtool
#       source: cask
#   - winget:
#       pkg: Microsoft.PowerToys
#       source: winget
#   type: tools
# - handle: zoom
#   methods:
#   - brew:
#       pkg: zoom
#       source: cask
#   - winget:
#       pkg: Zoom.Zoom
#       source: winget
#   type: tools
# - handle: restart-script
#   methods:
#   - bash:
#       script: restart-script.sh
#   - powershell:
#       script: restart-script.ps1
#   type: tools
# - handle: open-here-shell
#   methods:
#   - regedit:
#       script: open-here.reg
#   type: utilities

# %%
from munch import Munch
import yaml
toolYaml = Munch()

with open('tools.yaml') as f:
    toolYaml = Munch.fromYAML(f)


valid = toolYaml['valid']
components = toolYaml['components']
os_methods = toolYaml['os_methods']
stages = toolYaml['stages']
flows = toolYaml['flows']

# %%
valid = toolYaml['valid']
components = toolYaml['components']
os_methods = toolYaml['os_methods']
stages = toolYaml['stages']
flows = toolYaml['flows']

# %%
components.tools['azurecli']
# Out:
# Munch({'brew': Munch({'pkg': 'azure-cli'}), 'winget': Munch({'pkg': 'Microsoft.AzureCLI', 'source': '--source winget'})})

# %%
from munch import Munch
import yaml
import logging
import re


toolYaml = Munch()

class BraceMessage:
    def __init__(self, fmt, /, *args, **kwargs):
        self.fmt = fmt
        self.args = args
        self.kwargs = kwargs

    def __str__(self):
        return self.fmt.format(*self.args, **self.kwargs)

__ = BraceMessage
    

with open('tools.yaml') as f:
    toolYaml = Munch.fromYAML(f)

valid = toolYaml['valid']
methods = toolYaml['methods']
components = toolYaml['components']
os_methods = toolYaml['os_methods']
stages = toolYaml['stages']
flows = toolYaml['flows']




def install_components(target_components, target_os, group):
    calls = []
    for target_component in target_components:
        call = component_call(logger, target_component, target_os, group)
        if call is not None:
            calls.append(call)
    return calls

def collect_components(stage_list, component_type):
    if type(stage_list) is str:
        stage_list = [stage_list]
    target_components = []
    for stage in stage_list:
        if stage not in stages:
            logger.error(__(f'echo {stage} not found in stages'))
        if component_type not in stages[stage]:
            logger.error(__(f'echo {component_type} not found in {stage}'))
        target_components += stages[stage][component_type]
    return target_components

def collect_group_components(logger, stage, target_os):
    component_calls = []
    for group in stages[stage].keys():
        logger.debug(stage, group)
        component_calls += install_components(collect_components(stage, group), target_os, group)
    return component_calls

def missing_parameters(called_parameters, required_parameters):
    return list(set(called_parameters).difference(set(called_parameters)))

def execute_flow(logger, flow, target_os):
    if flow not in flows:
        logger.error(__(f'{flow} not found in flows'))
    if target_os not in os_methods.keys():
        logger.error(__(f'echo {target_os} not found in os_methods'))
    all_installs = []
    for stage in flows[flow]:
        if stage not in stages:
            logger.error(__(f'echo {stage} not found in stages'))
        all_installs += collect_group_components(logger, stage, target_os)
    return all_installs

def compose_call(logger, target_method_name, invoked_call_parameters):
    if target_method_name in methods:
        # if target_method_name == "compound-command":
        #     return compose_call(logger, invoked_call_parameters['componentA'], invoked_call_parameters['argsA']) + compose_call(logger, invoked_call_parameters['componentA'], invoked_call_parameters['argsB'])
        target_method_definition = methods[target_method_name]
        # allowed_method_params_dict = method_definition_dict['params']
        target_method_call_string = target_method_definition['call']
        called_parameters = invoked_call_parameters.keys()
        
        target_method_parameter_names = []
        required_parameters = []
        default_parameters_dicts = []
        default_parameters = []
        param_to_call_dict = {}
        
        for param in target_method_definition['params'].items():
            param_name, param_dict = param
            target_method_parameter_names.append(param_name)
            if {'required': True} in [param_dict]:
                required_parameters.append(param_name)
            if 'default' in param_dict:
                default_parameters_dicts.append(param)
        for param_name, param_dict in default_parameters_dicts:
            default_parameters.append(param_name)
            param_to_call_dict.update({param_name:param_dict['default']})
            
        missing_called_parameters = missing_parameters(called_parameters, required_parameters)
        invoked_target_parameter_names = list(set(called_parameters).intersection(set(target_method_parameter_names)))     
        empty_target_parameter_names = list(set(target_method_parameter_names).difference(set(invoked_target_parameter_names+default_parameters)))     
        out_of_scope_params = list(set(called_parameters).difference(set(target_method_parameter_names)))
        
        logger.debug(__('compose_call - called_parameters:'+ ' '.join(called_parameters)))
        logger.debug(__('compose_call - default_parameters:'+ ' '.join( default_parameters)))
        logger.debug(__('compose_call - missing_called_parameters:'+ ' '.join( called_parameters)+ ' difference '+ ' '.join( required_parameters)+ " equals "+ ' '.join( missing_called_parameters)))
        logger.debug(__('compose_call - invoked_target_parameter_names:'+ ' '.join( called_parameters)+ ' difference '+ ' '.join( target_method_parameter_names)+ " equals "+ ' '.join( invoked_target_parameter_names)))
        logger.debug(__('compose_call - empty_target_parameter_names:', target_method_parameter_names, ' difference ', invoked_target_parameter_names+default_parameters, " equals ", empty_target_parameter_names))

        
        if missing_called_parameters:
            logger.error(__(f"echo required parameters: {missing_called_parameters} not found in defined invoked_call_parameters"))
        
        if empty_target_parameter_names:
            for parameter_name in empty_target_parameter_names:
                param_to_call_dict.update({parameter_name:""})

        # if out_of_scope_params:
        #     logger.error(__(f"echo unrecognized parameters: [{out_of_scope_params}] for method {method}"
        if invoked_target_parameter_names:
            for parameter_name in invoked_target_parameter_names:
                compound_command = re.search("(?<=(component\()).*,.*(?=\))",  invoked_call_parameters[parameter_name])
                if compound_command is not None:
                    compound_command_parts = re.split(', *', compound_command[0])
                    param_to_call_dict.update({parameter_name:re.split('component\(', invoked_call_parameters[parameter_name])[0] + component_call(logger,compound_command_parts[1],group=compound_command_parts[0],target_method=compound_command_parts[2])})
                else:
                    param_to_call_dict.update({parameter_name:invoked_call_parameters[parameter_name]})
            logger.debug(__('combining call string:', target_method_call_string, param_to_call_dict))
            return target_method_call_string.format(**param_to_call_dict)
        else:  
            logger.error(__(f"echo {target_method_name} - did not find invoked_target_parameter_names - "+ ' '.join( invoked_call_parameters)))
    else:
        logger.error(__(f"echo {target_method_name} not found in defined methods"))
        
def component_call(logger, component, target_os=None, group='components', target_method = None):
    if target_method is not None:
        logger.debug(__(f'calling compose call with {target_method}'))
        call = compose_call(logger, target_method, components[group][component][target_method])
        if call is None:
            logger.error(__(f'compose_call returned None, component call with component:{component}, target_os:{target_os}, group:{group}, target_method:{target_method}'))
        else:
            return call
    else:
        if target_os not in os_methods.keys():
            logger.error(__(f'echo {target_os} not found in os_methods'))
        if group not in components:
            logger.error(__(f'echo {group} not found in component groups'))
        if component not in components[group]:
            logger.error(__(f'echo {group} has no found component {component}'))
        target_methods = components[group][component]
        component_method_set = set(target_methods.keys())
        os_method_set = set(os_methods[target_os])
        if bool(component_method_set & os_method_set):
            target_method = list(component_method_set.intersection(os_method_set))[0]
            call = compose_call(logger, target_method, target_methods[target_method])
            if call is None:
                logger.error(__(f'compose_call returned None, component call with component:{component}, target_os:{target_os}, group:{group}, target_method:{target_method}'))
            else:
                return call
        else:
            logger.error(__(f'echo {component} has no found method for {target_os}'))
        
# test 
import unittest

class test_compose_call(unittest.TestCase):
    logger = logging.getLogger(__name__)
    def extract_methods(methods, methods_to_extract=None):
        if methods_to_extract is None:
            methods_to_extract = methods.keys()
        if type(methods_to_extract) == str:
            methods_to_extract = [methods_to_extract]
        return_methods = {}
        for method in methods_to_extract:
            return_methods.update({method:methods[method]})
        return return_methods

    methods = {'winget': {'params': {'args': {'required': False},
                    'source': {'required': False, 'default': '--source winget'},
                    'pkg': {'required': True}},
                    'call': 'winget install {pkg} {source} {args}'},
                    'brew': {'params': {'args': {'required': False},
                    'source': {'required': False},
                    'pkg': {'required': True}},
                    'call': 'brew install {source} {pkg} -y {args}'}}
    components = {'tools':{'chrome': {'brew': {'pkg': 'google-chrome', 'source': '--cask'},
                    'winget': {'pkg': 'Google.Chrome', 'source': '--source winget'}},
                    'docker': {'brew': {'pkg': 'docker', 'source': '--cask'},
                    'winget': {'pkg': 'Docker.DockerDesktop', 'source': '--source winget'}}}}
    def test_compose_call(self):
        assert compose_call(logger, 'brew',{'pkg':'test_package'}) == 'brew install  test_package -y '
        assert compose_call(logger, 'winget',{'pkg':'test_package', 'args': '-arg1 -arg2 val1 -arg3'}) == 'winget install test_package --source winget -arg1 -arg2 val1 -arg3'

    def component_batch_test():
        methods = {'winget': {'params': {'args': {'required': False},
                        'source': {'required': False, 'default': '--source winget'},
                        'pkg': {'required': True}},
                        'call': 'winget install {pkg} {source} {args}'},
                        'brew': {'params': {'args': {'required': False},
                        'source': {'required': False},
                        'pkg': {'required': True}},
                        'call': 'brew install {source} {pkg} -y {args}'}}
        components = {'tools': {'chrome': {'brew': {'pkg': 'google-chrome', 'source': '--cask'},
                        'winget': {'pkg': 'Google.Chrome', 'source': '--source winget'}},
                        'docker': {'brew': {'pkg': 'docker', 'source': '--cask'},
                        'winget': {'pkg': 'Docker.DockerDesktop', 'source': '--source winget'}}},
                        'devenv': {'python': {'bash': {'source': 'install-python.sh'},
                        'winget': {'pkg': 'Python.Python.3', 'source': '--source winget'}},
                        'conda': {'bash': {'source': 'install-conda.sh'}}}}
        os_methods = {'macos': ['apt', 'apt-get', 'bash', 'brew', 'vs-extension'],
                        'unix': ['apt', 'apt-get', 'bash', 'brew', 'vs-extension'],
                        'windows': ['powershell', 'winget', 'vs-extension', 'regedit']}
        response = []
        for group in components.keys():
            for component in components[group]:
                for target_os in os_methods.keys():
                    response.append(f"{target_os}, {group}, {component}: {component_call(logger, component, target_os, group)}")
        return response

    def test_component_call(self):
        assert component_call(logger, 'chrome','windows','tools') == 'winget install Google.Chrome --source winget '
        assert component_batch_test() == [
            'macos, tools, chrome: brew install --cask google-chrome -y ',
            'unix, tools, chrome: brew install --cask google-chrome -y ',
            'windows, tools, chrome: winget install Google.Chrome --source winget ',
            'macos, tools, docker: brew install --cask docker -y ',
            'unix, tools, docker: brew install --cask docker -y ',
            'windows, tools, docker: winget install Docker.DockerDesktop --source winget ',
            'macos, devenv, python: bash -c install-python.sh ',
            'unix, devenv, python: bash -c install-python.sh ',
            'windows, devenv, python: winget install Python.Python.3 --source winget ',
            'macos, devenv, conda: bash -c install-conda.sh ',
            'unix, devenv, conda: bash -c install-conda.sh ',
            'windows, devenv, conda: echo conda has no found method for windows']

# compose_call(logger, 'winget',{'pkg':'test_package', 'args': '-arg1 -arg2 val1 -arg3'})

# %%
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

__ = BraceMessage
logger.setLevel(logging.INFO)
# # collect_group_components(logger, 'base', 'macos')
# collect_group_components(logger, 'data', 'macos')
execute_flow(logger, 'data', 'macos')
# Out:
# ERROR:__main__:echo ssh has no found method for macos
# ERROR:__main__:echo wsl-setup has no found method for macos
# ERROR:__main__:echo open-here-shell has no found method for macos
# ['bash -c restart-source.sh ',
#  'brew install --cask google-chrome -y ',
#  'brew install --cask notion -y ',
#  'brew install --cask google-drive -y ',
#  'brew install --cask miro -y ',
#  'brew install --cask vlc -y ',
#  'brew install --cask easyfind -y ',
#  'brew install --cask bettertouchtool -y ',
#  'brew install  sevenzip -y ',
#  'brew install --cask coteditor -y ',
#  'brew install --cask disk-inventory-x -y ',
#  'brew install --cask sejda-pdf -y ',
#  'brew install --cask visual-studio-code -y ',
#  'brew install --cask docker -y ',
#  'brew install  git -y ',
#  'brew install --cask github -y ',
#  'brew install  azure-cli -y ',
#  'brew install --cask postman -y ',
#  'bash -c devenv.sh ',
#  'bash -c install-python.sh ',
#  'bash -c install-conda.sh ',
#  'sudo apt-get install openjdk-11-jdk -y ',
#  'sudo apt-get install maven -y ',
#  'code --install-extension code --install-extension pa-data-team.vsix',
#  'brew install --cask dbeaver-community -y ',
#  'brew install --cask microsoft-azure-storage-explorer -y ',
#  'bash -c install-oraclejava8.sh ']

# %%
sting = ' -e compound-command(maven, apt-get)'
reg ="(?<=(compound-command\()).*,.*(?=\))"
import re
m = re.search(reg, sting)
if m is not None:
    print(True, m[0])
else:
    print(False)
# Out:
# True maven, apt-get

# %%
re.split('compound-command\(', sting)
# Out:
# [' -e ', 'maven, apt-get)']

# %%
collect_groups(flows['dev'])
# Out:
# ['tools', 'tools', 'devenv', 'tools', 'utilities', 'ide-extensions', 'tools']

# %%
execute_flow(logger, 'dev', 'macos')
# Out:
# ERROR:__main__:echo ssh has no found method for macos
# ERROR:__main__:echo wsl-setup has no found method for macos
# ERROR:__main__:echo open-here-shell has no found method for macos
# ['bash -c restart-source.sh ',
#  'brew install --cask google-chrome -y ',
#  'brew install --cask notion -y ',
#  'brew install --cask google-drive -y ',
#  'brew install --cask miro -y ',
#  'brew install --cask vlc -y ',
#  'brew install --cask easyfind -y ',
#  'brew install --cask bettertouchtool -y ',
#  'brew install  sevenzip -y ',
#  'brew install --cask coteditor -y ',
#  'brew install --cask disk-inventory-x -y ',
#  'brew install --cask sejda-pdf -y ',
#  'brew install --cask visual-studio-code -y ',
#  'brew install --cask docker -y ',
#  'brew install  git -y ',
#  'brew install --cask github -y ',
#  'brew install  azure-cli -y ',
#  'brew install --cask postman -y ',
#  'bash -c devenv.sh ',
#  'bash -c install-python.sh ',
#  'bash -c install-conda.sh ',
#  'sudo apt-get install openjdk-11-jdk -y ',
#  'sudo apt-get install maven -y ',
#  'code --install-extension code --install-extension pa-data-team.vsix',
#  'brew install --cask dbeaver-community -y ',
#  'brew install --cask microsoft-azure-storage-explorer -y ']

# %%
extract_methods(os_methods.toDict())
# Out:
# {'macos': ['apt', 'apt-get', 'bash', 'brew', 'vs-extension'],
#  'unix': ['apt', 'apt-get', 'bash', 'brew', 'vs-extension'],
#  'windows': ['powershell', 'winget', 'vs-extension', 'regedit']}

# %%
{'tools': (extract_methods(components['tools'].toDict(),["chrome",'docker'])), 'devenv': (extract_methods(components['devenv'].toDict(),["python",'conda']))}
# Out:
# {'tools': {'chrome': {'brew': {'pkg': 'google-chrome', 'source': '--cask'},
#    'winget': {'pkg': 'Google.Chrome', 'source': '--source winget'}},
#   'docker': {'brew': {'pkg': 'docker', 'source': '--cask'},
#    'winget': {'pkg': 'Docker.DockerDesktop', 'source': '--source winget'}}},
#  'devenv': {'python': {'bash': {'source': 'install-python.sh'},
#    'winget': {'pkg': 'Python.Python.3', 'source': '--source winget'}},
#   'conda': {'bash': {'source': 'install-conda.sh'}}}}

# %%
['methods':{'params': {'args': {'required': False},
  'source': {'required': False, 'default': '--source winget'},
  'pkg': {'required': True}},
 'call': 'winget install {pkg} {source} {args}'}}

# %%
target_method_definition = methods['winget'].toDict()
target_method_parameter_names = []
required_parameters = []
default_parameters = []
param_to_call_dict = {}
for param in target_method_definition['params'].items():
    param_name, param_dict = param
    target_method_parameter_names.append(param_name)
    if {'required': True} in [param_dict]:
        required_parameters.append(param_name)
    if 'default' in param_dict:
        default_parameters.append(param)
default_parameters
for param_name, param_dict in default_parameters:
    param_to_call_dict.update({param_name:param_dict['default']})
    
print(
    target_method_parameter_names ,
    required_parameters ,
    default_parameters ,
    param_to_call_dict 
)
# Out:
# ['args', 'source', 'pkg'] ['pkg'] [('source', {'required': False, 'default': 'winget'})] {'source': 'winget'}

# %%
# Out:
# invoked_call_parameter_names dict_keys(['pkg'])
# target_method_default_params_to_call_names ['source']
# missing_invoked_call_parameter_names: dict_keys(['pkg']) difference ['pkg'] equals []
# invoked_target_parameter_names: dict_keys(['pkg']) difference ['args', 'source', 'pkg'] equals ['pkg']
# empty_target_parameter_names: ['args', 'source', 'pkg'] difference ['pkg', 'source'] equals ['args']
# winget install {pkg} {source} {args} {'source': 'winget', 'args': '', 'pkg': 'test_package'}
# winget install test_package winget

# %%
install_components(flow_components('data', 'tools'), 'macos','tools')
# Out:
# ['brew install google-chrome -y ',
#  'brew install notion -y ',
#  'brew install google-drive -y ',
#  'brew install miro -y ',
#  'bash -c install-python.sh ',
#  'brew install vlc -y ',
#  'brew install easyfind -y ',
#  'brew install bettertouchtool -y ',
#  'brew install sevenzip -y ',
#  'brew install coteditor -y ',
#  'brew install disk-inventory-x -y ',
#  'brew install sejda-pdf -y ',
#  'brew install visual-studio-code -y ',
#  'brew install docker -y ',
#  'brew install git -y ',
#  'brew install github -y ',
#  'echo ssh has no found method for macos',
#  'brew install azure-cli -y ',
#  'brew install postman -y ',
#  'bash -c devenv.sh ',
#  'brew install dbeaver-community -y ',
#  'brew install microsoft-azure-storage-explorer -y ']
